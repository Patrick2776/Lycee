# %% [markdown]
# # Statistiques

# %% [markdown]
# Préambule: vous avez copié ce fichier dans vos documents et vous l'avez renommé sous la forme Stat_Nom

# %% [markdown]
# ### Fréquence:
#
# Si vous avez besoin de revoir la définition, aller ici https://mathenpoche.sesamath.net/?page=cinquieme#cinquieme_2_2_1

# %% [markdown]
# ### Exercice: Utilisation du tableur
#
# Aller ici https://mep-outils.sesamath.net/manuel_numerique/diapo.php?atome=83962&ordre=1 et faites l'exercice.

# %% [markdown]
# ### Exercice: Utilisation de python
#
# Aller ici https://mep-outils.sesamath.net/manuel_numerique/diapo.php?atome=83963&ordre=1.
#
# Ecrire le programme proposé ci-dessous. Pour le lancer il suffira de sélectionner la cellule et de cliquer sur run.

# %%
import random
effectif=0
for i in range(10):
    effectif=effectif+1
print.......

# %% [markdown]
# Ecrire dans la cellule ci-dessous le programme modifié

# %% [markdown]
# ### Moyenne simple:
#
# Vous savez tous calculer la moyenne de 10 et 18, c'est $\frac{10+18}{2}=14$.
#
# Ecrire dans la cellule ci-dessous une fonction python nommée moyenne2 qui prend 2 paramètres et retourne la moyenne de ces 2 valeurs.
#
# Par exemple moyenne2(10,14) devra retourner 12

# %%
def moyenne2()

# %%
moyenne2(10,18)

# %% [markdown]
# Ecrire dans la cellule ci-dessous une fonction python nommée moyenne3 qui prend 3 paramètres et retourne la moyenne de ces 3 valeurs.
#
# Par exemple moyenne3(10,12,14) devra retourner 12

# %%
def moyenne3()

# %%
moyenne3(10,14,18)

# %% [markdown]
# Lorsque l'on a plus de paramètres, on va utiliser des listes.
#
# Voici un exemple de liste en python: L=[7,15,14,18,5]
#
# Cette liste est appelée L et elle comprend 5 valeurs.
#
# L[0] est le premier terme de la liste et vaut 7
#
# L[3] est le quatrième  terme de la liste et vaut 18
#
# On obtient la longueur d'une liste par la commande len

# %%
L=[7,15,14,18,5]
len(L)

L[2]

# %% [markdown]
# Pour parcourir tous les élèments d'une liste il suffit de faire l'une des deux  boucles ci-dessous:

# %%
L=[1,4,9,16,25,36]
for i in L:
    print(i)

# %%
L=[1,4,9,16,25,36]
for i in range(len(L)):
    print(L[i])

# %% [markdown]
# Compléter le programme ci-dessous pour qu'il calcule la moyenne des nombres contenus dans la liste L.
#
# Par exemple moyenne([8,10,12,14]) renverra 11.

# %%
def moyenne(L):
    somme=0
    for i in range(len(L)):
        somme=somme+
    return somme/

# %%
moyenne([2,4,6,8,10])

# %% [markdown]
# ### Moyenne pondérée
#
# Si vous ne vous souvenez plus, aller ici https://mathenpoche.sesamath.net/?page=quatrieme#quatrieme_2_2_2
#
# Créer une fonction python nommée moyenne_pondere_3 prenant 6 paramètres et retournant la moyenne pondérée.
#
# Par exemple moyenne_ponderee_3(10,2,11,0.5,20,1) devra retourner la moyenne  pondérée
#
# de la note 10 avec le coefficient 2
#
# de la note 11 avec le coefficient 0.5
#
# de la note 20 avec le coefficient 1

# %%
def moyenne_ponderee_3():

# %%
moyenne_ponderee_3(10,2,11,0.5,20,1)

# %% [markdown]
# On peut aussi créer une fonction moyenne_ponderee prenant en paramètres 2 listes: les valeurs pour l'une et les coefficients pour l'autre.
#
# Par exemple moyenne_ponderee([10,12,13],[1,0.5,4]) devra retourner

# %%
def moyenne_ponderee(valeurs,coefficient):
