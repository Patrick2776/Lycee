# %% [markdown]
# # Statistique Suite

# %% [markdown]
# ## La médiane, les quartiles:
#
# Pour revoir les définitions c'est ici https://mathenpoche.sesamath.net/?page=seconde#seconde_5_2_1

# %% [markdown]
# Définition de la médiane:

# %% [markdown]
# Définition du premier quartile:

# %% [markdown]
# Définition du troisième quartile:

# %% [markdown]
# Définition de l'écart interquartile:

# %% [markdown]
# ### Exercice avec le tableur:
#
# Suivre ce lien https://mep-outils.sesamath.net/manuel_numerique/diapo.php?atome=83839&ordre=1

# %% [markdown]
# ### Exercice avec python:

# %% [markdown]
# Pour déterminer la médiane, il faut que la série statistique soit ordonnée.
#
# Il y a plusieurs algorithmes pour trier une liste de nombres. Nous utiliserons le tri par sélection: http://lwh.free.fr/pages/algo/tri/tri_insertion.html
#
# Recopier ici le programme python que vous avez trouvé sur le site précédent et testez le dans la cellule suivante.

# %%
def tri_insertion(tableau):
    
    
    
    return tableau

# %%
tri_insertion([4,5,6,7,1,2])

# %% [markdown]
# Créer à l'aide de cette fonction de tri, la fonction nommée mediane qui retourne la médiane de la série statistique contenue dans la liste serie.
#
# On pourra utiliser l'instruction // qui donne le quotient de la division euclidienne.
#
# Par exemple:
#
# 11//5 donnera 2 et non 2.5
#
# 7//2 donera 3 et non 3.5

# %%
11//5

# %%
7//2

# %%
def mediane(serie):
    # on trie la série
    serie_triee=tri_insertion(serie)
    
    # si l'effectif de la série est impaire, alors la médiane est..
    if len(serie_triee)%2==1:
        valeur_mediane=
    # sinon, l'effectif est paire et la médiane est ....   
    else:
        
        
    return valeur_mediane

# %%
mediane([4,5,6,7,1,2,3])

# %%
mediane([4,5,6,1,2,3])

# %% [markdown]
# Créer alors les fonctions python nommée premier_quartile, troisieme_quartile et ecart_interquartile calculant les 1er et 3ème quartile d'une série statistique, ainsi que l'ecart interquartile:

# %%
def premier_quartile(serie):

# %%
def troisieme_quartile(serie):

# %%
def ecart_interquartile(serie):

# %%
serie=[10,12,1,7,8,20,14,9,4,15,16,16,18,17,3]

premier_quartile(serie)

# %%
troisieme_quartile(serie)

# %%
ecart_interquartile(serie)
