# %% [markdown]
# # Ecart-type
#
# ### Avec le tableur:
#
# https://mep-outils.sesamath.net/manuel_numerique/diapo.php?atome=83838&ordre=1
#
# Définition de l'écart-type: https://mep-outils.sesamath.net/manuel_numerique/diapo.php?atome=83843&ordre=1

# %% [markdown]
# ### Avec la calculatrice:
#
# https://mep-outils.sesamath.net/manuel_numerique/diapo.php?atome=83926&ordre=1

# %% [markdown]
# ### Exercice:
#
# Prendre plusieurs séries statistiques au hasard et calculer moyenne et ecart-type avec tableur et calculatrice.

# %% [markdown]
# ### Avec python:
#
# Créer une fonction python nommée ecart_type qui prend en 2 paramètres 2 listes, l'une de valeurs et l'autre d'effectif et qui retourne l'écart-type

# %%
import maths

def moyenne(valeur,effectif):
    somme=0
    effectif_total=0
    for i in range(len(valeur)):
        effectif_total=effectif_total+effectif[i]
        somme=somme+valeur[i]*effectif[i]
    return somme/effectif_total
    


def ecart_type(valeur,effectif):
    somme=0
    for i in range(len(valeur)):
        somme=somme+()

# %%
ecart_type([10,14,12],[4,2,3])
